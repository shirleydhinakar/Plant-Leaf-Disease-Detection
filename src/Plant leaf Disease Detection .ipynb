# %% [markdown]
# ## Installing Requires Modules

# %%
pip install opencv-python
# Out:
# Collecting opencv-pythonNote: you may need to restart the kernel to use updated packages.
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\91914\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %% [markdown]
#  ## Importing Required Libraries

# %%
import pandas as pd
import cv2
import glob
import os
import numpy as np
import skimage.feature as feature
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as pt

#Classifiers
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt

#Performance Metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# Providing the required file locations
pp_and_fe = 'C:/Shirley/Karunya/Results/Projects/Preprocessing and Feature Extraction'
dataset = 'C:/Shirley/Karunya/Results/Projects/RiceLeafsv3'

# %% [markdown]
#  ## Preprocessing Images

# %%
# Creating the Preprocessing Folder
new_path = os.path.join(pp_and_fe, 'Preprocessed_RiceLeafsv')
os.mkdir(new_path)
print("Preprocessing Images")
# Accessing the test and train datasets
for i in os.listdir(dataset):
    
    #Initializing column arrays
    blue_mean = []
    blue_std = []
    red_mean = []
    red_std = []
    green_mean = []
    green_std = []
    area = []
    perimeter = []
    ratio_green = []
    non_green_ratio = []
    glcm_contrast = []
    glcm_dissimilarity = []
    glcm_homogeneity = []
    glcm_energy = []
    glcm_correlation = []
    dis_type = []
    
    i_path = os.path.join(new_path, i)
    os.mkdir(i_path)
    # Accessing Disease Datasets
    for j in os.listdir(dataset+"/"+i):
        j_path = os.path.join(i_path, j)
        os.mkdir(j_path)
        fin = dataset+"/"+i+"/"+j
        fin_len = len(fin)
        
        #Setting selected variabele
        set = 0
        
        for img in glob.glob(fin+"/*.jpg"):
            #Reading Image
            image = cv2.imread(img)
            cv2.imshow('Original Image', image)
            cv2.waitKey(30)
            #Resizing Image
            img_res = cv2.resize(image, (400, 400))
            cv2.imshow('Resized Image', img_res)
            
            ############################################################
            # COLOR FEATURES- MEAN & STD
            blue_mean.append(np.mean(img_res[:, :, 0]))
            blue_std.append(np.std(img_res[:, :, 0]))
            green_mean.append(np.mean(img_res[:, :, 1]))
            green_std.append(np.std(img_res[:, :, 1]))
            red_mean.append(np.mean(img_res[:, :, 2]))
            red_std.append(np.std(img_res[:, :, 2]))
            ############################################################
            cv2.waitKey(30)
            #Converting to Grayscale
            img_gray = cv2.cvtColor(img_res, cv2.COLOR_BGR2GRAY)
            cv2.imshow('Grayscale Image', img_gray)
            cv2.waitKey(30)
            #Applying GaussianBlur
            img_gau = cv2.GaussianBlur(img_gray,(5,5),0)
            cv2.imshow('Blurred Image', img_gau)
            cv2.waitKey(30)
            #Applying Otsu's Thresholding for binarizing the image
            T, img_otsu = cv2.threshold(img_gau, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
            cv2.imshow('Binarized Image', img_otsu)
            cv2.waitKey(30)
            #Applying Morphological Transform on image
            kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
            img_morph = cv2.morphologyEx(img_otsu, cv2.MORPH_CLOSE, kernel)
            cv2.imshow("Morphological Transformed Image: (3,3)", img_morph)
            
            ############################################################
            # SHAPE FEATURES- CONTOURING
            contours,hierarchy = cv2.findContours(img_morph, 1, 2)
            cnt = contours[0]
            area.append(cv2.contourArea(cnt))
            perimeter.append(cv2.arcLength(cnt,True))
            ############################################################
            cv2.waitKey(30)
            #Applying Bitwise AND
            img_bit = cv2.bitwise_and(img_res, img_res, mask = img_morph)
            cv2.imshow("Bitwise AND Image: ", img_bit)
            cv2.waitKey(30)
            #HSV Image Conversion (NEED TO SAVE)
            img_hsv = cv2.cvtColor(img_res, cv2.COLOR_BGR2HSV)
            cv2.imshow("HSV Image: ", img_hsv)
            
            ############################################################
            # GREEN AMOUNT IN IMAGE
            
            hsv_hue = img_hsv[:, :, 0]
            green = 0
            non_green = 0
            for r in hsv_hue:
                for c in r:
                    if c>30 and c<70:
                        green +=1
                    else:
                        non_green += 1

            ratio_green.append(green/(green+non_green))
            non_green_ratio.append(non_green/(green+non_green))
            ############################################################
            cv2.waitKey(30)
            ############################################################
            #Texture Features - GLCM

            gray = cv2.cvtColor(img_bit, cv2.COLOR_BGR2GRAY)
            graycom = feature.graycomatrix(gray, [1], [0])

            glcm_contrast.append(feature.graycoprops(graycom, 'contrast')[0][0])
            glcm_dissimilarity.append(feature.graycoprops(graycom, 'dissimilarity')[0][0])
            glcm_homogeneity.append(feature.graycoprops(graycom, 'homogeneity')[0][0])
            glcm_energy.append(feature.graycoprops(graycom, 'energy')[0][0])
            glcm_correlation.append(feature.graycoprops(graycom, 'correlation')[0][0])
            ############################################################
            
            dis_type.append(j)
            
            #Saving Sample Images
            if set == 0:
                cv2.imwrite(j_path+"/original_"+img[fin_len+1:], image)
                cv2.imwrite(j_path+"/resize_"+img[fin_len+1:], img_res)
                cv2.imwrite(j_path+"/grayscale_"+img[fin_len+1:], img_gray)
                cv2.imwrite(j_path+"/blurred_"+img[fin_len+1:], img_gau)
                cv2.imwrite(j_path+"/thresholded_"+img[fin_len+1:], img_otsu)
                cv2.imwrite(j_path+"/morphed_"+img[fin_len+1:], img_morph)
                cv2.imwrite(j_path+"/bit_"+img[fin_len+1:], img_bit)
                cv2.imwrite(j_path+"/hsv_"+img[fin_len+1:], img_hsv)
            set = 1

        cv2.destroyAllWindows()
    out = {
            'blueMean' : blue_mean,
            'blueStd' : blue_std,
            'redMean' : red_mean,
            'redStd' : red_std,
            'greenMean' : green_mean,
            'greenStd' : green_std,
            'imgArea' : area,
            'imgPer' : perimeter,
            'greenRatio' : ratio_green,
            'nonGreenRatio' : non_green_ratio,
            'contrast' : glcm_contrast,
            'dissimilarity' : glcm_dissimilarity,
            'homogeneity' : glcm_homogeneity,
            'energy' : glcm_energy, 
            'correlation' : glcm_correlation,
            'diseaseType' : dis_type
        }
    print("{} Dataset Preprocessing completed. Writing data into {}.csv...".format(i,i))
    file_name = i+".csv"
    print("Writing into {}.csv complete.".format(i,i))
    df = pd.DataFrame(out)
    df.to_csv(file_name, mode='a', index=False)
# Out:
# Preprocessing Images
# test Dataset Preprocessing completed. Writing data into test.csv...
# Writing into test.csv complete.
# train Dataset Preprocessing completed. Writing data into train.csv...
# Writing into train.csv complete.

# %% [markdown]
# # *RUN FROM HERE*-----)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Train Dataset

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#      blueMean    blueStd     redMean     redStd   greenMean   greenStd  \
# 0  118.009000  94.339131  173.414631  60.295073  170.755262  51.157559
# 1  189.396381  57.559923  220.132275  27.995296  205.709519  26.488245
# 2  117.345681  92.126354  168.607237  62.995784  169.259038  51.802334
# 3  161.178638  83.380784  199.099181  56.736703  191.201325  47.733643
# 4  180.314638  68.730966  215.386212  42.125207  202.910981  37.863636
#
#    imgArea     imgPer  greenRatio  nonGreenRatio    contrast  dissimilarity  \
# 0     35.5  23.899495    0.429644       0.570356  181.041779       4.093985
# 1     25.0  18.485281    0.010694       0.989306  139.117043       1.833208
# 2     18.0  15.656854    0.463112       0.536887  231.837180       3.219373
# 3    120.0  54.142135    0.239038       0.760962  172.285301       3.064273
# 4     30.0  21.656854    0.077269       0.922731  149.902807       1.742193
#
#    homogeneity    energy  correlation            diseaseType
# 0     0.555428  0.450265     0.972797  bacterial_leaf_blight
# 1     0.885426  0.867256     0.966177  bacterial_leaf_blight
# 2     0.613692  0.436208     0.963723  bacterial_leaf_blight
# 3     0.743836  0.684769     0.969706  bacterial_leaf_blight
# 4     0.845197  0.787961     0.971104  bacterial_leaf_blight

# %%
train.tail()
# Out:
#         blueMean    blueStd     redMean     redStd   greenMean   greenStd  \
# 2162  217.929600  81.346928  230.148438  55.055819  238.057337  38.247656
# 2163  236.606250  60.081289  242.691156  40.514295  246.604469  27.995809
# 2164  234.235463  60.846477  239.747588  45.213761  247.205369  23.907659
# 2165  230.795925  71.390634  239.752956  45.749735  240.194344  44.407593
# 2166  231.368306  66.364326  238.660450  46.254963  240.388706  41.557309
#
#       imgArea      imgPer  greenRatio  nonGreenRatio    contrast  \
# 2162  27078.0  952.568542    0.166681       0.833319  223.740100
# 2163  13213.5  872.041630    0.084300       0.915700  139.106491
# 2164  16177.0  885.941125    0.104525       0.895475  209.953296
# 2165  15990.0  884.142135    0.069681       0.930319  167.798283
# 2166  17561.0  751.740114    0.088025       0.911975  101.430288
#
#       dissimilarity  homogeneity    energy  correlation        diseaseType
# 2162       3.743722     0.843562  0.824901     0.955250  narrow_brown_spot
# 2163       1.802870     0.920801  0.911988     0.948598  narrow_brown_spot
# 2164       2.895865     0.898807  0.893385     0.947649  narrow_brown_spot
# 2165       2.957531     0.899786  0.894544     0.914444  narrow_brown_spot
# 2166       1.442055     0.905202  0.885666     0.960815  narrow_brown_spot

# %%
train.shape
# Out:
# (2167, 16)

# %%
print("No. of duplicates before drop: ", train.duplicated().sum())
print("Size: ", train.shape)
train = train.drop_duplicates()
print("Size: ", train.shape)
print("No. of duplicates after drop: ", train.duplicated().sum())
# Out:
# No. of duplicates before drop:  167
# Size:  (2167, 16)
# Size:  (2000, 16)
# No. of duplicates after drop:  0

# %%
print("NA values: ", train.isna().sum().sum())
# Out:
# NA values:  0

# %%
le = LabelEncoder()
train["diseaseTypeEncoded"] = le.fit_transform(train["diseaseType"])

# %%
train_label = train.drop_duplicates(subset = ["diseaseType"])[["diseaseType","diseaseTypeEncoded"]]
train_label
# Out:
#                 diseaseType  diseaseTypeEncoded
# 0     bacterial_leaf_blight                   0
# 350              brown_spot                   1
# 723                 healthy                   2
# 1094             leaf_blast                   3
# 1457             leaf_scald                   4
# 1815      narrow_brown_spot                   5

# %%
train.columns
# Out:
# Index(['blueMean', 'blueStd', 'redMean', 'redStd', 'greenMean', 'greenStd',
#        'imgArea', 'imgPer', 'greenRatio', 'nonGreenRatio', 'contrast',
#        'dissimilarity', 'homogeneity', 'energy', 'correlation', 'diseaseType',
#        'diseaseTypeEncoded'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 2166
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   blueMean            2000 non-null   float64
#  1   blueStd             2000 non-null   float64
#  2   redMean             2000 non-null   float64
#  3   redStd              2000 non-null   float64
#  4   greenMean           2000 non-null   float64
#  5   greenStd            2000 non-null   float64
#  6   imgArea             2000 non-null   float64
#  7   imgPer              2000 non-null   float64
#  8   greenRatio          2000 non-null   float64
#  9   nonGreenRatio       2000 non-null   float64
#  10  contrast            2000 non-null   float64
#  11  dissimilarity       2000 non-null   float64
#  12  homogeneity         2000 non-null   float64
#  13  energy              2000 non-null   float64
#  14  correlation         2000 non-null   float64
#  15  diseaseType         2000 non-null   object
#  16  diseaseTypeEncoded  2000 non-null   int32
# dtypes: float64(15), int32(1), object(1)
# memory usage: 273.4+ KB

# %%
train.describe()
# Out:
#           blueMean      blueStd      redMean       redStd    greenMean  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    203.024678    68.918348   216.922565    43.250088   216.810466
# std      29.526015    15.635300    23.173702    12.253701    23.656309
# min      15.330113    12.795018    96.510594     9.291409   109.954400
# 25%     185.859667    58.001902   199.099570    34.622346   198.178977
# 50%     203.236591    70.268904   217.727356    43.210792   212.673950
# 75%     226.992689    79.945677   238.654591    51.782148   240.390317
# max     248.109056   112.081470   253.306706    84.976954   252.565575
#
#           greenStd        imgArea       imgPer   greenRatio  nonGreenRatio  \
# count  2000.000000    2000.000000  2000.000000  2000.000000    2000.000000
# mean     39.268945   15088.881500   618.515843     0.156579       0.843421
# std      10.719228   15317.199029   489.677044     0.140506       0.140506
# min      10.103639       0.000000     0.000000     0.000019       0.079269
# 25%      31.300219      50.000000    30.727922     0.070688       0.811814
# 50%      38.756194   14796.250000   890.681239     0.120775       0.879225
# 75%      46.820216   25109.875000  1032.811182     0.188186       0.929312
# max      85.017841  101108.500000  1574.357426     0.920731       0.999981
#
#           contrast  dissimilarity  homogeneity       energy  correlation  \
# count  2000.000000    2000.000000  2000.000000  2000.000000  2000.000000
# mean    166.450321       2.257308     0.861405     0.827770     0.953736
# std     126.209527       1.465463     0.068456     0.096661     0.025620
# min       4.778784       0.208772     0.541526     0.157149     0.813951
# 25%      89.131717       1.356823     0.832176     0.789767     0.939690
# 50%     133.742475       1.912356     0.875041     0.849314     0.956520
# 75%     206.898155       2.700832     0.910692     0.891323     0.970160
# max     909.011140      10.278346     0.970499     0.962519     0.998989
#
#        diseaseTypeEncoded
# count         2000.000000
# mean             2.525500
# std              1.671151
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              4.000000
# max              5.000000

# %%
train.iloc[:,:15].median()
# Out:
# blueMean           203.236591
# blueStd             70.268904
# redMean            217.727356
# redStd              43.210792
# greenMean          212.673950
# greenStd            38.756194
# imgArea          14796.250000
# imgPer             890.681239
# greenRatio           0.120775
# nonGreenRatio        0.879225
# contrast           133.742475
# dissimilarity        1.912356
# homogeneity          0.875041
# energy               0.849314
# correlation          0.956520
# dtype: float64

# %%
train.mode()
# Out:
#       blueMean    blueStd     redMean     redStd   greenMean   greenStd  \
# 0   149.821650  45.310881  167.052787  23.067525  188.140838  23.010551
# 1   179.514837  48.479042  185.954700  23.074969  189.203644  23.014786
# 2   179.717637  51.256952  186.458031  24.608333  199.003263  24.659117
# 3   199.527488  54.876708  187.705594  24.710053  200.707444  24.661939
# 4   203.136675  58.160807  204.194038  24.713443  202.364756  27.619746
# ..         ...        ...         ...        ...         ...        ...
# 57         NaN        NaN         NaN        NaN         NaN        NaN
# 58         NaN        NaN         NaN        NaN         NaN        NaN
# 59         NaN        NaN         NaN        NaN         NaN        NaN
# 60         NaN        NaN         NaN        NaN         NaN        NaN
# 61         NaN        NaN         NaN        NaN         NaN        NaN
#
#     imgArea     imgPer  greenRatio  nonGreenRatio   contrast  dissimilarity  \
# 0      14.0  13.656854    0.050569       0.907225   7.955157       0.311078
# 1       NaN        NaN    0.092775       0.949431   8.611761       0.363703
# 2       NaN        NaN         NaN            NaN  11.168716       0.410739
# 3       NaN        NaN         NaN            NaN  11.510238       0.473684
# 4       NaN        NaN         NaN            NaN  13.620063       0.478158
# ..      ...        ...         ...            ...        ...            ...
# 57      NaN        NaN         NaN            NaN        NaN       2.292143
# 58      NaN        NaN         NaN            NaN        NaN       4.607218
# 59      NaN        NaN         NaN            NaN        NaN       4.884085
# 60      NaN        NaN         NaN            NaN        NaN       5.129286
# 61      NaN        NaN         NaN            NaN        NaN       6.884499
#
#     homogeneity    energy  correlation diseaseType  diseaseTypeEncoded
# 0      0.757871  0.607489     0.888740     healthy                 2.0
# 1      0.784821  0.691087     0.889550         NaN                 NaN
# 2      0.792306  0.694319     0.920281         NaN                 NaN
# 3      0.800641  0.726758     0.934114         NaN                 NaN
# 4      0.804076  0.731141     0.942260         NaN                 NaN
# ..          ...       ...          ...         ...                 ...
# 57          NaN       NaN          NaN         NaN                 NaN
# 58          NaN       NaN          NaN         NaN                 NaN
# 59          NaN       NaN          NaN         NaN                 NaN
# 60          NaN       NaN          NaN         NaN                 NaN
# 61          NaN       NaN          NaN         NaN                 NaN
#
# [62 rows x 17 columns]

# %%
train.iloc[:,:15].var()
# Out:
# blueMean         8.717856e+02
# blueStd          2.444626e+02
# redMean          5.370205e+02
# redStd           1.501532e+02
# greenMean        5.596209e+02
# greenStd         1.149018e+02
# imgArea          2.346166e+08
# imgPer           2.397836e+05
# greenRatio       1.974202e-02
# nonGreenRatio    1.974202e-02
# contrast         1.592884e+04
# dissimilarity    2.147581e+00
# homogeneity      4.686229e-03
# energy           9.343382e-03
# correlation      6.563703e-04
# dtype: float64

# %% [markdown]
# Test Dataset

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#      blueMean    blueStd     redMean     redStd   greenMean   greenStd  \
# 0  196.546206  49.645478  219.282525  35.982502  206.637075  29.569100
# 1  130.272956  94.797624  184.926787  53.409677  183.818494  47.226956
# 2  129.845694  93.786567  186.858725  53.496543  182.911487  46.496280
# 3  137.318263  93.914314  182.392388  66.406792  180.227756  54.380679
# 4  161.178638  83.380784  199.099181  56.736703  191.201325  47.733643
#
#    imgArea      imgPer  greenRatio  nonGreenRatio    contrast  dissimilarity  \
# 0     14.0   13.656854    0.072400       0.927600   92.011190       1.480113
# 1   2301.0  259.539103    0.394356       0.605644  244.160414       4.815952
# 2     40.5   23.899495    0.318419       0.681581  180.958396       2.338145
# 3    161.0   57.313708    0.379050       0.620950  255.051479       6.047469
# 4    120.0   54.142135    0.239038       0.760962  172.285301       3.064273
#
#    homogeneity    energy  correlation            diseaseType
# 0     0.918402  0.908237     0.949673  bacterial_leaf_blight
# 1     0.551938  0.429280     0.972725  bacterial_leaf_blight
# 2     0.682696  0.492356     0.977813  bacterial_leaf_blight
# 3     0.609522  0.568873     0.955236  bacterial_leaf_blight
# 4     0.743836  0.684769     0.969706  bacterial_leaf_blight

# %%
test.tail()
# Out:
#        blueMean    blueStd     redMean     redStd   greenMean   greenStd  \
# 538  204.084325  89.977550  219.801506  62.762971  223.402631  56.671522
# 539  206.452031  84.862041  221.532975  59.646435  239.598906  28.551773
# 540  213.162225  85.520091  227.093669  57.512889  235.950356  39.808390
# 541  219.467013  78.847018  230.439681  54.941718  233.070100  49.291978
# 542  180.383725  98.205113  215.024875  56.273579  228.780719  37.708081
#
#      imgArea       imgPer  greenRatio  nonGreenRatio    contrast  \
# 538  38284.5  1007.154328    0.184744       0.815256  125.131115
# 539  38981.5  1006.325901    0.248344       0.751656  293.671090
# 540  30128.0   959.112698    0.188906       0.811094  170.378358
# 541  26481.0   950.225396    0.129988       0.870012  133.625627
# 542     52.0    30.485281    0.321169       0.678831  283.896992
#
#      dissimilarity  homogeneity    energy  correlation        diseaseType
# 538       2.252155     0.798348  0.754552     0.973954  narrow_brown_spot
# 539       5.355789     0.763544  0.750150     0.968225  narrow_brown_spot
# 540       2.602657     0.834141  0.805756     0.967536  narrow_brown_spot
# 541       2.061642     0.855062  0.828664     0.963431  narrow_brown_spot
# 542       4.512431     0.683326  0.627977     0.976457  narrow_brown_spot

# %%
test.shape
# Out:
# (543, 16)

# %%
print("No. of duplicates before drop: ", test.duplicated().sum())
print("Size: ", test.shape)
test = test.drop_duplicates()
print("Size: ", test.shape)
print("No. of duplicates after drop: ", test.duplicated().sum())
# Out:
# No. of duplicates before drop:  12
# Size:  (543, 16)
# Size:  (531, 16)
# No. of duplicates after drop:  0

# %%
print("NA values: ", test.isna().sum().sum())
# Out:
# NA values:  0

# %%
test["diseaseTypeEncoded"] = le.fit_transform(test["diseaseType"])

# %%
test_label = test.drop_duplicates(subset = ["diseaseType"])[["diseaseType","diseaseTypeEncoded"]]
test_label
# Out:
#                diseaseType  diseaseTypeEncoded
# 0    bacterial_leaf_blight                   0
# 88              brown_spot                   1
# 181                healthy                   2
# 274             leaf_blast                   3
# 365             leaf_scald                   4
# 455      narrow_brown_spot                   5

# %%
test.columns
# Out:
# Index(['blueMean', 'blueStd', 'redMean', 'redStd', 'greenMean', 'greenStd',
#        'imgArea', 'imgPer', 'greenRatio', 'nonGreenRatio', 'contrast',
#        'dissimilarity', 'homogeneity', 'energy', 'correlation', 'diseaseType',
#        'diseaseTypeEncoded'],
#       dtype='object')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531 entries, 0 to 542
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   blueMean            531 non-null    float64
#  1   blueStd             531 non-null    float64
#  2   redMean             531 non-null    float64
#  3   redStd              531 non-null    float64
#  4   greenMean           531 non-null    float64
#  5   greenStd            531 non-null    float64
#  6   imgArea             531 non-null    float64
#  7   imgPer              531 non-null    float64
#  8   greenRatio          531 non-null    float64
#  9   nonGreenRatio       531 non-null    float64
#  10  contrast            531 non-null    float64
#  11  dissimilarity       531 non-null    float64
#  12  homogeneity         531 non-null    float64
#  13  energy              531 non-null    float64
#  14  correlation         531 non-null    float64
#  15  diseaseType         531 non-null    object
#  16  diseaseTypeEncoded  531 non-null    int32
# dtypes: float64(15), int32(1), object(1)
# memory usage: 72.6+ KB

# %%
test.describe()
# Out:
#          blueMean     blueStd     redMean      redStd   greenMean    greenStd  \
# count  531.000000  531.000000  531.000000  531.000000  531.000000  531.000000
# mean   203.086140   68.782834  217.857806   42.919680  217.359937   39.165646
# std     30.774170   15.590538   23.467215   12.072130   24.251782   10.864993
# min     40.395150   25.147090   96.517794   10.231676  110.017988   10.114371
# 25%    185.769534   57.213061  199.356619   34.385748  198.589253   30.790310
# 50%    204.451019   70.294170  217.971244   42.178770  213.418494   38.877176
# 75%    230.262016   80.503836  239.956637   51.018907  241.882487   45.989753
# max    247.880906  107.165783  252.491381   81.894361  252.477975   74.448306
#
#              imgArea       imgPer  greenRatio  nonGreenRatio    contrast  \
# count     531.000000   531.000000  531.000000     531.000000  531.000000
# mean    15281.560264   620.558213    0.156838       0.843162  165.561932
# std     15937.911271   482.605935    0.136485       0.136485  122.782869
# min         0.000000     0.000000    0.000037       0.182562    5.959806
# 25%        47.750000    31.192388    0.067166       0.811028   90.012249
# 50%     13841.000000   881.798990    0.119181       0.880819  135.839649
# 75%     26214.000000  1025.760930    0.188972       0.932834  201.493528
# max    101855.500000  1348.492422    0.817438       0.999962  844.913264
#
#        dissimilarity  homogeneity      energy  correlation  diseaseTypeEncoded
# count     531.000000   531.000000  531.000000   531.000000          531.000000
# mean        2.242245     0.860044    0.825657     0.953439            2.500942
# std         1.394910     0.071357    0.099648     0.027359            1.691683
# min         0.224806     0.551859    0.222544     0.849535            0.000000
# 25%         1.373891     0.825367    0.787260     0.939486            1.000000
# 50%         1.957074     0.875296    0.847266     0.956840            2.000000
# 75%         2.737365     0.913211    0.895673     0.970825            4.000000
# max         9.089774     0.967885    0.962550     0.998771            5.000000

# %%
test.iloc[:,:15].median()
# Out:
# blueMean           204.451019
# blueStd             70.294170
# redMean            217.971244
# redStd              42.178770
# greenMean          213.418494
# greenStd            38.877176
# imgArea          13841.000000
# imgPer             881.798990
# greenRatio           0.119181
# nonGreenRatio        0.880819
# contrast           135.839649
# dissimilarity        1.957074
# homogeneity          0.875296
# energy               0.847266
# correlation          0.956840
# dtype: float64

# %%
test.mode()
# Out:
#        blueMean     blueStd     redMean     redStd   greenMean   greenStd  \
# 0    212.532531   25.147090  233.746719  38.558804  231.671388  28.848452
# 1    234.053844   32.240342  246.577250        NaN  245.192544        NaN
# 2           NaN   33.306208         NaN        NaN         NaN        NaN
# 3           NaN   33.319193         NaN        NaN         NaN        NaN
# 4           NaN   33.698367         NaN        NaN         NaN        NaN
# ..          ...         ...         ...        ...         ...        ...
# 526         NaN  100.776907         NaN        NaN         NaN        NaN
# 527         NaN  102.592376         NaN        NaN         NaN        NaN
# 528         NaN  104.359752         NaN        NaN         NaN        NaN
# 529         NaN  104.849726         NaN        NaN         NaN        NaN
# 530         NaN  107.165783         NaN        NaN         NaN        NaN
#
#      imgArea     imgPer  greenRatio  nonGreenRatio    contrast  dissimilarity  \
# 0       14.0  13.656854    0.044906       0.823956   12.619029       0.694179
# 1        NaN        NaN    0.071081       0.871463  104.419148       1.124962
# 2        NaN        NaN    0.080562       0.882787  124.001955       1.957074
# 3        NaN        NaN    0.086837       0.895100  158.981040       1.996629
# 4        NaN        NaN    0.104900       0.913162  451.535965       2.278045
# ..       ...        ...         ...            ...         ...            ...
# 526      NaN        NaN         NaN            NaN         NaN            NaN
# 527      NaN        NaN         NaN            NaN         NaN            NaN
# 528      NaN        NaN         NaN            NaN         NaN            NaN
# 529      NaN        NaN         NaN            NaN         NaN            NaN
# 530      NaN        NaN         NaN            NaN         NaN            NaN
#
#      homogeneity    energy  correlation diseaseType  diseaseTypeEncoded
# 0       0.761769  0.731855     0.920592     healthy                 2.0
# 1       0.827491  0.746936     0.971358         NaN                 NaN
# 2       0.831859  0.798996     0.982705         NaN                 NaN
# 3       0.877089  0.872865     0.988698         NaN                 NaN
# 4       0.905984  0.880606     0.998095         NaN                 NaN
# ..           ...       ...          ...         ...                 ...
# 526          NaN       NaN          NaN         NaN                 NaN
# 527          NaN       NaN          NaN         NaN                 NaN
# 528          NaN       NaN          NaN         NaN                 NaN
# 529          NaN       NaN          NaN         NaN                 NaN
# 530          NaN       NaN          NaN         NaN                 NaN
#
# [531 rows x 17 columns]

# %%
test.iloc[:,:15].var()
# Out:
# blueMean         9.470496e+02
# blueStd          2.430649e+02
# redMean          5.507102e+02
# redStd           1.457363e+02
# greenMean        5.881489e+02
# greenStd         1.180481e+02
# imgArea          2.540170e+08
# imgPer           2.329085e+05
# greenRatio       1.862822e-02
# nonGreenRatio    1.862822e-02
# contrast         1.507563e+04
# dissimilarity    1.945774e+00
# homogeneity      5.091804e-03
# energy           9.929645e-03
# correlation      7.485083e-04
# dtype: float64

# %%
corr = train.corr()
plt.figure(figsize=(16, 12))
sns.heatmap(corr, annot = True, cmap="coolwarm")
plt.show()

# %% [markdown]
# 0.967198- "greenMean","redMean"
#
# 0.879862- "greenMean", "blueMean"
#
# 0.943726- "energy","homogenity"
#
# 0.902633- "dissimilarity", "contrast"
#
#
#
# 0.860521- "imgArea","imgPer"
#
# 0.845422- "redMean", "blueMean"
#
# 0.822998- "greenStd", "redStd"

# %%
corr_test = test.corr()
corr_test.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_013e0_row0_col0, #T_013e0_row1_col1, #T_013e0_row2_col2, #T_013e0_row3_col3, #T_013e0_row4_col4, #T_013e0_row5_col5, #T_013e0_row6_col6, #T_013e0_row7_col7, #T_013e0_row8_col8, #T_013e0_row9_col9, #T_013e0_row10_col10, #T_013e0_row11_col11, #T_013e0_row12_col12, #T_013e0_row13_col13, #T_013e0_row14_col14, #T_013e0_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col2 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col3, #T_013e0_row1_col0, #T_013e0_row3_col0, #T_013e0_row5_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col4 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col5, #T_013e0_row7_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col6, #T_013e0_row13_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_013e0_row0_col8, #T_013e0_row4_col7, #T_013e0_row9_col1, #T_013e0_row9_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col10, #T_013e0_row9_col10, #T_013e0_row9_col15 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_013e0_row0_col11, #T_013e0_row5_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_013e0_row0_col12 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col13 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col14, #T_013e0_row1_col15, #T_013e0_row13_col14 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_013e0_row0_col15, #T_013e0_row4_col15, #T_013e0_row15_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_013e0_row1_col2, #T_013e0_row11_col14 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_013e0_row1_col3 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_013e0_row1_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_013e0_row1_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_013e0_row1_col6, #T_013e0_row8_col5 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_013e0_row1_col7 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_013e0_row1_col8 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_013e0_row1_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_013e0_row1_col10, #T_013e0_row8_col11 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_013e0_row1_col11 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_013e0_row1_col12, #T_013e0_row1_col13, #T_013e0_row2_col6, #T_013e0_row7_col10, #T_013e0_row8_col0, #T_013e0_row8_col2, #T_013e0_row8_col4, #T_013e0_row8_col9, #T_013e0_row8_col15, #T_013e0_row9_col8, #T_013e0_row10_col7, #T_013e0_row10_col14, #T_013e0_row12_col1, #T_013e0_row12_col3, #T_013e0_row12_col5, #T_013e0_row12_col11, #T_013e0_row14_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_013e0_row1_col14 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_013e0_row2_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col1, #T_013e0_row6_col11 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col3, #T_013e0_row2_col5, #T_013e0_row6_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col4, #T_013e0_row4_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col7, #T_013e0_row11_col12, #T_013e0_row13_col11, #T_013e0_row14_col0, #T_013e0_row14_col4, #T_013e0_row14_col11, #T_013e0_row15_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col9 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col10, #T_013e0_row4_col10, #T_013e0_row14_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_013e0_row2_col11, #T_013e0_row7_col13, #T_013e0_row11_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_013e0_row2_col12 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_013e0_row2_col13 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col14, #T_013e0_row4_col14, #T_013e0_row8_col13, #T_013e0_row12_col14 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_013e0_row2_col15 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_013e0_row3_col1, #T_013e0_row5_col1 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col4, #T_013e0_row5_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col5, #T_013e0_row5_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col6, #T_013e0_row7_col8 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_013e0_row3_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_013e0_row3_col8, #T_013e0_row15_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_013e0_row3_col9, #T_013e0_row10_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_013e0_row3_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_013e0_row3_col11 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_013e0_row3_col12, #T_013e0_row9_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col13, #T_013e0_row4_col6, #T_013e0_row5_col15 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_013e0_row3_col14 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_013e0_row3_col15, #T_013e0_row11_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col5, #T_013e0_row5_col13 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col8, #T_013e0_row14_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_013e0_row4_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_013e0_row4_col12 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_013e0_row4_col13 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_013e0_row5_col0, #T_013e0_row6_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_013e0_row5_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_013e0_row5_col6, #T_013e0_row8_col6, #T_013e0_row8_col14 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_013e0_row5_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_013e0_row5_col8 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_013e0_row5_col10, #T_013e0_row11_col13 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_013e0_row5_col11 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_013e0_row5_col14 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_013e0_row6_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_013e0_row6_col1, #T_013e0_row8_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_013e0_row6_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_013e0_row6_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_013e0_row6_col5, #T_013e0_row15_col13 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_013e0_row6_col7 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_013e0_row6_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_013e0_row6_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_013e0_row6_col12 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_013e0_row6_col13 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_013e0_row6_col14, #T_013e0_row10_col4, #T_013e0_row10_col9 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_013e0_row6_col15 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_013e0_row7_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_013e0_row7_col1, #T_013e0_row11_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_013e0_row7_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_013e0_row7_col3 {
#   background-color:

# %% [markdown]
# 0.972983- "greenMean","redMean"
#
# 0.908223- "greenMean", "blueMean"
#
# 0.946458- "energy","homogenity"
#
# 0.896572- "dissimilarity", "contrast"
#
#
#
# 0.868422- "redMean", "blueMean"
#
# 0.852880- "greenStd", "redStd"
#
# 0.845152- "imgArea","imgPer"

# %%
col = ["blueMean","redMean","greenMean","contrast","dissimilarity","homogeneity","energy"]
X_train = train[col]
X_test = test[col]

# %%
Y_train = train["diseaseTypeEncoded"]
Y_test = test["diseaseTypeEncoded"]

# %% [markdown]
# K-NN Classifier:

# %% [markdown]
# k = 3

# %%
knn_3 = KNeighborsClassifier(n_neighbors=3)
knn_3.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn_3 = knn_3.predict(X_test)

# %%
conf_mat_knn_3 = confusion_matrix(Y_test, y_pred_knn_3)
conf_mat_knn_3
# Out:
# array([[79,  1,  0,  0,  3,  1],
#        [ 6, 65,  6,  8,  1,  5],
#        [ 0, 11, 71, 11,  0,  0],
#        [ 2, 12, 17, 51,  3,  3],
#        [ 0,  1,  1,  2, 79,  5],
#        [ 0,  5,  0,  1,  6, 75]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_knn_3, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_knn_3))
# print(metrics.classification_report(Y_test, y_pred_knn_3, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_knn_3, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_knn_3, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_knn_3, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7909604519774012
# Precision:  0.7899412237922688
# Recall:  0.7929240762944878
# f1 score:  0.7903018943379022

# %% [markdown]
# k = 5

# %%
knn_5 = KNeighborsClassifier(n_neighbors=5)
knn_5.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn_5 = knn_5.predict(X_test)

# %%
conf_mat_knn_5 = confusion_matrix(Y_test, y_pred_knn_5)
conf_mat_knn_5
# Out:
# array([[79,  0,  0,  0,  3,  2],
#        [ 8, 64,  6,  8,  0,  5],
#        [ 0,  8, 78,  7,  0,  0],
#        [ 4, 16, 19, 41,  6,  2],
#        [ 1,  0,  1,  2, 80,  4],
#        [ 1,  5,  0,  2,  7, 72]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_knn_5, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_knn_5))
# print(metrics.classification_report(Y_test, y_pred_knn_5, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_knn_5, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_knn_5, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_knn_5, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7796610169491526
# Precision:  0.7752266497997048
# Recall:  0.7808447963481334
# f1 score:  0.7735023812507423

# %% [markdown]
# k = 7

# %%
knn_7 = KNeighborsClassifier(n_neighbors=7)
knn_7.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_knn_7 = knn_7.predict(X_test)

# %%
conf_mat_knn_7 = confusion_matrix(Y_test, y_pred_knn_7)
conf_mat_knn_7
# Out:
# array([[78,  0,  0,  0,  4,  2],
#        [10, 60,  5, 10,  1,  5],
#        [ 0,  8, 78,  7,  0,  0],
#        [ 4,  9, 21, 39,  9,  6],
#        [ 1,  0,  1,  2, 80,  4],
#        [ 0,  3,  0,  1, 11, 72]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_knn_7, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_knn_7))
# print(metrics.classification_report(Y_test, y_pred_knn_7, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_knn_7, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_knn_7, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_knn_7, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7664783427495292
# Precision:  0.760579549229791
# Recall:  0.7677467832501205
# f1 score:  0.7581331188613865

# %% [markdown]
# k = 9

# %%
knn_9 = KNeighborsClassifier(n_neighbors=9)
knn_9.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred_knn_9 = knn_9.predict(X_test)

# %%
conf_mat_knn_9 = confusion_matrix(Y_test, y_pred_knn_9)
conf_mat_knn_9
# Out:
# array([[76,  0,  0,  0,  6,  2],
#        [11, 55,  5,  9,  1, 10],
#        [ 0, 10, 75,  8,  0,  0],
#        [ 4,  9, 19, 42,  8,  6],
#        [ 1,  0,  1,  4, 78,  4],
#        [ 0,  3,  0,  1,  9, 74]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_knn_9, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_knn_9))
# print(metrics.classification_report(Y_test, y_pred_knn_9, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_knn_9, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_knn_9, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_knn_9, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7532956685499058
# Precision:  0.7470269810822879
# Recall:  0.7549700330567961
# f1 score:  0.7463379534770587

# %% [markdown]
# k = 11

# %%
knn_11 = KNeighborsClassifier(n_neighbors=11)
knn_11.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred_knn_11 = knn_11.predict(X_test)

# %%
conf_mat_knn_11 = confusion_matrix(Y_test, y_pred_knn_11)
conf_mat_knn_11
# Out:
# array([[75,  0,  0,  0,  7,  2],
#        [12, 52,  6,  9,  2, 10],
#        [ 0,  6, 79,  8,  0,  0],
#        [ 3,  8, 22, 41,  9,  5],
#        [ 2,  0,  0,  4, 76,  6],
#        [ 0,  3,  0,  1, 10, 73]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_knn_11, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_knn_11))
# print(metrics.classification_report(Y_test, y_pred_knn_11, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_knn_11, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_knn_11, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_knn_11, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7457627118644068
# Precision:  0.7415229808248398
# Recall:  0.747062332365447
# f1 score:  0.7374666598675935

# %% [markdown]
# Support Vector Classifier:

# %%
rbf_svc = SVC(kernel='rbf', gamma=0.7, C=2)
rbf_svc.fit(X_train, Y_train)
# Out:
# SVC(C=2, gamma=0.7)

# %%
poly_svc = SVC(kernel='poly', degree=3, C=15)
poly_svc.fit(X_train, Y_train)
# Out:
# SVC(C=15, kernel='poly')

# %%
y_pred_rbf_svc = rbf_svc.predict(X_test)
y_pred_poly_svc = poly_svc.predict(X_test)

# %%
conf_mat_rbf_svc = confusion_matrix(Y_test, y_pred_rbf_svc)
conf_mat_poly_svc = confusion_matrix(Y_test, y_pred_poly_svc)
print("RBF: \n", conf_mat_rbf_svc)
print("Polynomial: \n", conf_mat_poly_svc)
# Out:
# RBF:
#  [[67  0 17  0  0  0]
#  [ 0 46 45  0  0  0]
#  [ 0  0 92  1  0  0]
#  [ 0  0 48 40  0  0]
#  [ 0  0 17  0 71  0]
#  [ 0  0 27  0  0 60]]
# Polynomial:
#  [[78  0  0  0  6  0]
#  [ 4 66  8  0  1 12]
#  [ 0  8 83  2  0  0]
#  [ 0 22 43  6  9  8]
#  [ 0  2  0  1 82  3]
#  [ 0  4  0  1 14 68]]

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_rbf_svc, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_rbf_svc))
# print(metrics.classification_report(Y_test, y_pred_rbf_svc, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_rbf_svc, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_rbf_svc, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_rbf_svc, average='macro', pos_label=1))

plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_poly_svc, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_poly_svc))
# print(metrics.classification_report(Y_test, y_pred_poly_svc, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_poly_svc, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_poly_svc, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_poly_svc, average='macro', pos_label=1))
# Out:
# Accuracy:  0.7080979284369114
# Precision:  0.8915989159891599
# Recall:  0.7072299456198232
# f1 score:  0.7385477094989219
# Accuracy:  0.7212806026365348
# Precision:  0.7161794875324609
# Recall:  0.7213214112546704
# f1 score:  0.6769113860717474

# %% [markdown]
# Naive- Bayes Classifier:

# %%
nb = GaussianNB()
nb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(X_test)

# %%
conf_mat_nb = confusion_matrix(Y_test, y_pred_nb)
conf_mat_nb
# Out:
# array([[47,  0, 20,  9,  4,  4],
#        [10, 16, 32,  5,  6, 22],
#        [ 5,  0, 83,  5,  0,  0],
#        [ 5,  2, 38, 20, 16,  7],
#        [ 2,  1,  0,  0, 71, 14],
#        [ 2,  4,  0,  0, 41, 40]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_nb, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_nb))
# print(metrics.classification_report(Y_test, y_pred_nb, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_nb, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_nb, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_nb, average='macro', pos_label=1))
# Out:
# Accuracy:  0.5216572504708098
# Precision:  0.5540793620687261
# Recall:  0.5202803546101655
# f1 score:  0.48571047443328585

# %% [markdown]
# Decision Tree Classifier:

# %%
dtree = DecisionTreeClassifier(random_state=42)
dtree = dtree.fit(X_train, Y_train)

# %%
y_pred_dtree = dtree.predict(X_test)

# %%
conf_mat_dtree = confusion_matrix(Y_test, y_pred_dtree)
conf_mat_dtree
# Out:
# array([[80,  2,  0,  0,  2,  0],
#        [ 4, 71,  6, 10,  0,  0],
#        [ 0,  6, 71, 16,  0,  0],
#        [ 1, 12, 10, 63,  0,  2],
#        [ 0,  0,  1,  0, 85,  2],
#        [ 0,  0,  0,  0,  6, 81]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_dtree, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_dtree))
# print(metrics.classification_report(Y_test, y_pred_dtree, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_dtree, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_dtree, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_dtree, average='macro', pos_label=1))
# Out:
# Accuracy:  0.8493408662900188
# Precision:  0.8504998787099612
# Recall:  0.8514823762320982
# f1 score:  0.850741186720541

# %% [markdown]
# Random forest Classifier:

# %%
rf = RandomForestClassifier(random_state=43)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=43)

# %%
y_pred_rf = rf.predict(X_test)

# %%
conf_mat_rf = confusion_matrix(Y_test, y_pred_rf)
conf_mat_rf
# Out:
# array([[82,  0,  0,  0,  2,  0],
#        [ 3, 78,  5,  5,  0,  0],
#        [ 0,  6, 79,  8,  0,  0],
#        [ 0, 10, 10, 68,  0,  0],
#        [ 1,  0,  0,  0, 86,  1],
#        [ 0,  0,  0,  0,  3, 84]], dtype=int64)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_rf, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,y_pred_rf))
print(metrics.classification_report(Y_test, y_pred_rf, digits=6))
print("Precision: ",precision_score(Y_test, y_pred_rf, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, y_pred_rf, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, y_pred_rf, average='macro', pos_label=1))
# Out:
# Accuracy:  0.8983050847457628
#               precision    recall  f1-score   support
#
#            0   0.953488  0.976190  0.964706        84
#            1   0.829787  0.857143  0.843243        91
#            2   0.840426  0.849462  0.844920        93
#            3   0.839506  0.772727  0.804734        88
#            4   0.945055  0.977273  0.960894        88
#            5   0.988235  0.965517  0.976744        87
#
#     accuracy                       0.898305       531
#    macro avg   0.899416  0.899719  0.899207       531
# weighted avg   0.897893  0.898305  0.897740       531
#
# Precision:  0.8994162583437615
# Recall:  0.8997188233840069
# f1 score:  0.8992067800497011

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 2)

# %%
# Fit the grid search to the data
grid_search.fit(X_train, Y_train)
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 1000}

# %%
rfc1=RandomForestClassifier(max_depth= 100, max_features= 3, min_samples_leaf= 3, min_samples_split= 8, n_estimators= 200,  bootstrap=True, random_state=43)

# %%
rfc1.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features=3, min_samples_leaf=3,
#                        min_samples_split=8, n_estimators=200, random_state=43)

# %%
pred=rfc1.predict(X_test)

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_mat_rf, annot=True, cmap = 'coolwarm')
plt.show()
print("Accuracy: ",accuracy_score(Y_test,pred))
print(metrics.classification_report(Y_test, pred, digits=6))
print("Precision: ",precision_score(Y_test, pred, average='macro', pos_label=1))
print("Recall: ",recall_score(Y_test, pred, average='macro', pos_label=1))
print("f1 score: ",f1_score(Y_test, pred, average='macro', pos_label=1))
# Out:
# Accuracy:  0.8587570621468926
#               precision    recall  f1-score   support
#
#            0   0.952941  0.964286  0.958580        84
#            1   0.747475  0.813187  0.778947        91
#            2   0.833333  0.806452  0.819672        93
#            3   0.772152  0.693182  0.730539        88
#            4   0.894737  0.965909  0.928962        88
#            5   0.963855  0.919540  0.941176        87
#
#     accuracy                       0.858757       531
#    macro avg   0.860749  0.860426  0.859646       531
# weighted avg   0.858962  0.858757  0.857915       531
#
# Precision:  0.8607489033008093
# Recall:  0.8604258798919533
# f1 score:  0.8596460871005337
